# %%
from triangle import *
from forward_2d_square import *
from forward_2d_triangle import *

# %%
import runpy
result = runpy._run_module_as_main("forward_2d_square")
# Out:
# [2.558904   2.25541081 3.2011    ]

# %%
result = runpy._run_module_as_main("forward_2d_triangle")
# Out:
# Computing chord 1...
# generating_points...
# computing normalized radii...
# Computing chord 2...
# generating_points...
# computing normalized radii...
# Computing chord 3...
# generating_points...
# computing normalized radii...
# [2.558664 2.255164 3.199544]
